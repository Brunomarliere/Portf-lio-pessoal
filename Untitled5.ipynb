# %% [markdown]
# <a href="https://colab.research.google.com/github/Brunomarliere/Portf-lio-pessoal/blob/main/Untitled5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random
pontos=0
resultado=0
operacao=0
operacao=(input('qual operaçao você deseja fazer (+, -, *, /): '))
continuacao=0

while True:
  s1=random.randint(1,100)
  s2=random.randint(1,100)
  s3=s2+s1
  s4=s2-s1
  s5=random.randint(1,100)
  s6=random.randint(1,10)
  s7=(s5/s6)
  s8=round(s7,1)
  s9=random.randint(1,10)
  s10=s6*s9
  #adiçao
  if(operacao=='+'):
      resultado=int(input(f'{s1}+{s2}='))
      if (resultado==s3):
        print('parabens você acertou')
        pontos=pontos+1
        print(f'você tem {pontos} pontos')
        continuacao=input("deseja continuar?(S/N)")
        if(continuacao=='S'):
          operacao=(input('qual operaçao você deseja fazer (+, -, *, /): '))
        elif(continuacao=='N'):
          print(f'você fez {pontos} pontos')
          break
        else:
          print('você não digitou nenhuma das opções começe de novo')
          operacao=(input('qual operaçao você deseja fazer (+, -, *, /): '))


      else:
        print('você perdeu')
        break


  elif(operacao=='-'):
      resultado=int(input(f'{s2}-{s1}='))
      if (resultado==s4):
        print('parabens você acertou')
        pontos=pontos+1
        print(f'você tem {pontos} pontos')
        continuacao=input("deseja continuar?(S/N)")
        if(continuacao=='S'):
          operacao=(input('qual operaçao você deseja fazer (+, -, *, /): '))
        elif(continuacao=='N'):
          print(f'você fez {pontos} pontos')
          break
        else:
          print('você não digitou nenhuma das opções começe de novo')
          operacao=(input('qual operaçao você deseja fazer (+, -, *, /): '))


      else:
        print('você perdeu')
        break



  elif(operacao=='/'):
      resultado=int(input(f'{s5}/{s6}='))
      if (resultado==s8):
        print('parabens você acertou')
        pontos=pontos+1
        print(f'você tem {pontos} pontos')
        continuacao=input("deseja continuar?(S/N)")
        if(continuacao=='S'):
          operacao=(input('qual operaçao você deseja fazer (+, -, *, /): '))
        elif(continuacao=='N'):
          print(f'você fez {pontos} pontos')
          break
        else:
          print('você não digitou nenhuma das opções começe de novo')
          operacao=(input('qual operaçao você deseja fazer (+, -, *, /): '))


      else:
        print('você perdeu')
        break


  elif(operacao=='*'):
      resultado=int(input(f'{s6}*{s9}='))
      if (resultado==s10):
        print('parabens você acertou')
        pontos=pontos+1
        print(f'você tem {pontos} pontos')
        continuacao=input("deseja continuar?(S/N)")
        if(continuacao=='S'):
          operacao=(input('qual operaçao você deseja fazer (+, -, *, /): '))
        elif(continuacao=='N'):
          print(f'você fez {pontos} pontos')
          break
        else:
          print('você não digitou nenhuma das opções começe de novo')
          operacao=(input('qual operaçao você deseja fazer (+, -, *, /): '))


      else:
        print('você perdeu')
        break


  else:
    print('digite uma operação')
    operacao=(input('qual operaçao você deseja fazer (+, -, *, /): '))
# Out:
# qual operaçao você deseja fazer (+, -, *, /): +
# 3+89=92
# parabens você acertou
# você tem 1 pontos
# deseja continuar?(S/N)S
# qual operaçao você deseja fazer (+, -, *, /): +
# 10+52=62
# parabens você acertou
# você tem 2 pontos
# deseja continuar?(S/N)*
# você não digitou nenhuma das opções começe de novo
# qual operaçao você deseja fazer (+, -, *, /): +
# 59+12=3
# você perdeu
